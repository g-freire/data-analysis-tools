# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import seaborn.apionly as sns
titanic = sns.load_dataset('titanic')
# Out:
# c:\python37\lib\site-packages\matplotlib\__init__.py:855: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# c:\python37\lib\site-packages\matplotlib\__init__.py:846: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   "2.2", name=key, obj_type="rcparam", addendum=addendum)
# c:\python37\lib\site-packages\seaborn\apionly.py:9: UserWarning: As seaborn no longer sets a default style on import, the seaborn.apionly module is deprecated. It will be removed in a future version.
#   warnings.warn(msg, UserWarning)

# %%
filepath = "museum-visitors.csv"
df = pd.read_csv(filepath, index_col="Timestamp", parse_dates=True)

# %%
df['2015':'2018'][-5:] # filtering with index
# Out:
#             America Tropical Interpretive Center  Avila Adobe  \
# Timestamp
# 2018-08-01                                  3891        20815
# 2018-09-01                                  3180        21020
# 2018-10-01                                  3775        19280
# 2018-11-01                                  4562        17163
# 2018-12-01                                  4081        17722
#
#             Chinese American Museum  Gateway to Nature Center  \
# Timestamp
# 2018-08-01                     2409                       NaN
# 2018-09-01                     2146                       NaN
# 2018-10-01                     2364                       NaN
# 2018-11-01                     2385                       NaN
# 2018-12-01                     2078                       NaN
#
#             Firehouse Museum  Hellman Quon   IAMLA  Pico House   \
# Timestamp
# 2018-08-01              4866           NaN  1147.0       1119.0
# ...

# %%
#plt.figure(figsize=(16,8))
#plt.title("Museum data")
columns = ['America Tropical Interpretive Center', 'Avila Adobe', 'Chinese American Museum','Gateway to Nature Center']
df_2 = df[columns]
#or df_2 = df.iloc[:,0:4]
sns.lineplot(data=df_2)

# %%
# Out:
#             America Tropical Interpretive Center  Avila Adobe  \
# Timestamp
# 2014-01-01                                  6602        24778
# 2014-02-01                                  5029        18976
# 2014-03-01                                  8129        25231
# 2014-04-01                                  2824        26989
# 2014-05-01                                 10694        36883
# 2014-06-01                                 11036        29487
# 2014-07-01                                 13490        32378
# 2014-08-01                                  9139        37680
# 2014-09-01                                  5661        28473
# 2014-10-01                                  7356        27995
# 2014-11-01                                  9773        25691
# 2014-12-01                                  7184        18754
# 2015-01-01                                  6250        20438
# 2015-02-01                                  5907        15578
# ...
